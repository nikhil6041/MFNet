# %% [markdown]
# Installing required packages

# %%
# !pip install facenet_pytorch pytorch_model_summary
# Out:
# Collecting facenet_pytorch
#   Downloading https://files.pythonhosted.org/packages/18/e8/5ea742737665ba9396a8a2be3d2e2b49a13804b56a7e7bb101e8731ade8f/facenet_pytorch-2.5.2-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 17.8MB/s
# Collecting pytorch_model_summary
#   Downloading https://files.pythonhosted.org/packages/fe/45/01d67be55fe3683a9221ac956ba46d1ca32da7bf96029b8d1c7667b8a55c/pytorch_model_summary-0.1.2-py3-none-any.whl
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from facenet_pytorch) (0.9.1+cu101)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from facenet_pytorch) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from facenet_pytorch) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from facenet_pytorch) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pytorch_model_summary) (4.41.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch_model_summary) (1.8.1+cu101)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->facenet_pytorch) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->facenet_pytorch) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->facenet_pytorch) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->facenet_pytorch) (2.10)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch_model_summary) (3.7.4.3)
# Installing collected packages: facenet-pytorch, pytorch-model-summary
# Successfully installed facenet-pytorch-2.5.2 pytorch-model-summary-0.1.2

# %% [markdown]
# Importing necessary packages

# %%
import numpy as np
import numpy as np
import pandas as pd

import os

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc
from matplotlib.ticker import MaxNLocator
from pylab import rcParams

import torch
import torchvision
import PIL

from torch import nn, optim
from torch import optim
from torch.optim.lr_scheduler import MultiStepLR
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms
import torch.nn.functional as F
import torchvision.transforms as T
from torch.utils.data import DataLoader,SubsetRandomSampler
from torchvision import models,datasets
from torch.optim import lr_scheduler

from facenet_pytorch import InceptionResnetV1, fixed_image_standardization
from pytorch_model_summary import summary

import random

import cv2
import PIL.Image as Image

from google.colab.patches import cv2_imshow

from sklearn.metrics import confusion_matrix, classification_report

from collections import defaultdict

# %% [markdown]
# Mounting the drive

# %%
from google.colab import drive 
drive.mount('/content/drive')
root_dir_path = os.path.join(os.getcwd(),'drive','MyDrive','Labelled Faces In The Wild Dataset')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Dataset Paths

# %%
original_dir_path = os.path.join(root_dir_path,'lfw-deepfunneled','lfw-deepfunneled')
original_cropped_dir_path = os.path.join(root_dir_path,'lfw-deepfunneled','lfw-deepfunneled_cropped')


surgical_masked_dir_path = os.path.join(root_dir_path,'lfw-deepfunneled','lfw-deepfunneled_masked_surgical')
surgical_masked_cropped_dir_path = os.path.join(root_dir_path,'lfw-deepfunneled','lfw-deepfunneled_masked_surgical_cropped')


KN95_masked_dir_path = os.path.join(root_dir_path,'lfw-deepfunneled','lfw-deepfunneled_masked_KN95')
KN95_masked_cropped_dir_path = os.path.join(root_dir_path,'lfw-deepfunneled','lfw-deepfunneled_masked_KN95_cropped')

# %% [markdown]
# Check for gpu availability

# %%
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4

# %% [markdown]
# Configuring some settings for visualization and seeding the values to makes the results as much reproducible as possible

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='darkgrid', palette='muted', font_scale=1.2)

colors_pallette = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]

sns.set_palette(sns.color_palette(colors_pallette))

rcParams['figure.figsize'] = 16, 12

seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %% [markdown]
# Helper Functions for training , validation and visualizations

# %%
def train_epoch(
  model, 
  data_loader, 
  criterion, 
  optimizer, 
  device, 
  n_examples
):
    model = model.train()

    losses = []
    correct_predictions = 0

    print(f'Doing training on {n_examples} samples')

    for batch_idx , (b_images,b_labels) in enumerate(data_loader):

        if batch_idx%10 == 0:
            print(f' Processing batch {batch_idx+1}/{len(data_loader)} ')

        b_images = b_images.to(device)
        b_labels = b_labels.to(device)


        outputs = model(b_images)
        _, b_preds = torch.max(outputs, 1)
        
        loss = criterion(outputs,b_labels)

        correct_predictions += torch.sum(b_preds == b_labels)

        losses.append(loss.item())

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    accuracy = correct_predictions.double() / n_examples
    loss = np.mean(losses)

    return accuracy , loss

# %%
def eval_model(
    model, 
    data_loader,
    criterion,
    device,
    n_examples):
    model = model.eval()

    losses = []
    correct_predictions = 0

    print(f'Doing validation on {n_examples} samples')

    with torch.no_grad():

        for batch_idx , (b_images,b_labels) in enumerate(data_loader):

            if batch_idx%10 == 0:
                print(f' Processing batch {batch_idx+1}/{len(data_loader)} ')

            b_images = b_images.to(device)
            b_labels = b_labels.to(device)


            outputs = model(b_images)
            _, b_preds = torch.max(outputs, 1)

            # print(b_preds.size())
            # print(b_labels.size())
            
            loss = criterion(outputs,b_labels)

            correct_predictions += torch.sum(b_preds == b_labels)

            losses.append(loss.item())
    
    accuracy = correct_predictions.double() / n_examples
    loss = round(np.mean(losses),2)

    return accuracy , loss

# %%
def train_model(
    model,
    train_data_loader,
    val_data_loader, 
    train_dataset_size,
    val_dataset_size,
    optimizer,
    criterion,
    scheduler,
    device, 
    n_epochs=3):

    history = defaultdict(list)

    best_accuracy = 0
    criterion.to(device)

    for epoch in range(n_epochs):

        print(f'Epoch {epoch + 1}/{n_epochs}')
        print('-' * 10)

        train_acc, train_loss = train_epoch(
                                    model, 
                                    train_data_loader, 
                                    criterion, 
                                    optimizer, 
                                    device, 
                                    train_dataset_size
                                )

        print("Train loss {:.2f} accuracy {:.2f}".format(train_loss,train_acc))

        val_acc, val_loss = eval_model(
                                    model, 
                                    val_data_loader, 
                                    criterion, 
                                    device, 
                                    val_dataset_size

                            )

        print("Validation  loss {:.2f} accuracy {:.2f}".format(val_loss,val_acc))
        
        print()

        scheduler.step(val_loss)

        history['train_acc'].append(train_acc)
        history['train_loss'].append(train_loss)
        history['val_acc'].append(val_acc)
        history['val_loss'].append(val_loss)

        if val_acc > best_accuracy:
            torch.save(model.state_dict(), 'best_model_state.bin')
            best_accuracy = val_acc

    print(f'Best val accuracy: {best_accuracy}')

    model.load_state_dict(torch.load('best_model_state.bin'))

    return model, history

# %%
def visualize_images(path,n_samples):
    '''
        path: expects list of paths to images or a single image's path
    '''
    cnt = 0
    for root,dirs,files in os.walk(path):
        for fname in files:
            if cnt == n_samples:
                return
            path = os.path.join(root,fname)
            img = cv2.imread(path, cv2.IMREAD_UNCHANGED)
            cv2_imshow(img)
          
            cnt += 1

# %%
def plot_training_history(history):
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

  ax1.plot(history['train_loss'], label='train loss')
  ax1.plot(history['val_loss'], label='validation loss')

  ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
  ax1.legend()
  ax1.set_ylabel('Loss')
  ax1.set_xlabel('Epoch')

  ax2.plot(history['train_acc'], label='train accuracy')
  ax2.plot(history['val_acc'], label='validation accuracy')

  ax2.xaxis.set_major_locator(MaxNLocator(integer=True))
  ax2.set_ylim([-0.05, 1.05])
  ax2.legend()

  ax2.set_ylabel('Accuracy')
  ax2.set_xlabel('Epoch')

  fig.suptitle('Training history')

# %%
def show_confusion_matrix(confusion_matrix, class_names):

  cm = confusion_matrix.copy()

  cell_counts = cm.flatten()

  cm_row_norm = cm / cm.sum(axis=1)[:, np.newaxis]

  row_percentages = ["{0:.2f}".format(value) for value in cm_row_norm.flatten()]

  cell_labels = [f"{cnt}\n{per}" for cnt, per in zip(cell_counts, row_percentages)]
  cell_labels = np.asarray(cell_labels).reshape(cm.shape[0], cm.shape[1])

  df_cm = pd.DataFrame(cm_row_norm, index=class_names, columns=class_names)

  hmap = sns.heatmap(df_cm, annot=cell_labels, fmt="", cmap="Blues")
  hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
  hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
  plt.ylabel('True Sign')
  plt.xlabel('Predicted Sign');

# %% [markdown]
# Visualize images from the directories

# %%
visualize_images(path = original_cropped_dir_path,n_samples= 1)
visualize_images(path = surgical_masked_cropped_dir_path , n_samples= 1)
visualize_images(path = KN95_masked_cropped_dir_path , n_samples= 1)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F16B40DD110>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F16B4133310>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F16B4131E50>

# %%
# dataset = datasets.ImageFolder(data_dir, transform=transforms.Resize((256, 256)))
# dataset.samples = [
#     (p, p.replace(data_dir, data_dir + '_cropped'))
#         for p, _ in dataset.samples
# ]
        
# loader = DataLoader(
#     dataset,
#     num_workers=workers,
#     batch_size=batch_size,
#     collate_fn=training.collate_pil
# )

# for i, (x, y) in enumerate(loader):
#     mtcnn(x, save_path=y)
#     print('\rBatch {} of {}'.format(i + 1, len(loader)), end='')
    
# # Remove mtcnn to reduce GPU memory usage
# del mtcnn

# %% [markdown]
# Preparing the dataset and dataloaders

# %%
batch_size = 64
validation_size = .2
test_size = 0.1
shuffle_dataset = True
data_dir = KN95_masked_cropped_dir_path
num_workers = 0 if os.name == 'nt' else 8

transformations  = T.Compose([
    T.Resize(size = 256),
    T.ToTensor(),
    fixed_image_standardization
])

dataset = datasets.ImageFolder(data_dir, transform=transformations)


dataset_size = len(dataset)

indices = np.arange(dataset_size)

test_split = int(np.floor(test_size*dataset_size))

train_indices = indices[test_split:]
test_indices = indices[:test_split]


# Creating data indices for training and validation splits:
train_val_dataset_size = len(train_indices)
train_val_indices = list(range(train_val_dataset_size))

val_split = int(np.floor(validation_size * train_val_dataset_size))

if shuffle_dataset :
    np.random.seed(seed_val)
    np.random.shuffle(train_val_indices)

train_indices, val_indices = train_val_indices[val_split:], train_val_indices[:val_split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)
test_sampler = SubsetRandomSampler(test_indices)

train_loader = torch.utils.data.DataLoader(
                                dataset, batch_size=batch_size, 
                                sampler=train_sampler,drop_last = True,
                                num_workers = num_workers
                )
validation_loader = torch.utils.data.DataLoader(
                                dataset, batch_size=batch_size,
                                sampler=valid_sampler,drop_last = True,
                                num_workers = num_workers
                    )

test_loader = torch.utils.data.DataLoader(
                                dataset, batch_size=batch_size,
                                sampler=valid_sampler,drop_last = True,
                                num_workers = num_workers
                    )
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
print("Total number of different identies in the dataset {}".format(len(dataset.class_to_idx)))
# Out:
# Total number of different identies in the dataset 5622

# %%
print("Total number of samples in the dataset {}".format(len(dataset.imgs)))
# Out:
# Total number of samples in the dataset 12962

# %% [markdown]
# Defining our model

# %%
model = InceptionResnetV1(
    classify=True,
    pretrained='vggface2',
    num_classes=len(dataset.class_to_idx)
).to(device)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=111898327.0), HTML(value='')))

# %%
print(model)
# Out:
# InceptionResnetV1(
#   (conv2d_1a): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2a): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2b): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (maxpool_3a): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2d_3b): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4a): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4b): BasicConv2d(
#     (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (repeat_1): Sequential(
#     (0): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_6a): Mixed_6a(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_2): Sequential(
#     (0): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (5): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (6): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (7): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (8): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (9): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_7a): Mixed_7a(
#     (branch0): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_3): Sequential(
#     (0): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (block8): Block8(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (avgpool_1a): AdaptiveAvgPool2d(output_size=1)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (last_linear): Linear(in_features=1792, out_features=512, bias=False)
#   (last_bn): BatchNorm1d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (logits): Linear(in_features=512, out_features=5622, bias=True)
# )

# %% [markdown]
# Keras type Model Summary

# %%
print(summary(model, torch.zeros((1, 3, 256, 256)).to(device), show_input=True))
# Out:
# ------------------------------------------------------------------------------
#            Layer (type)           Input Shape         Param #     Tr. Param #
# ==============================================================================
#           BasicConv2d-1      [1, 3, 256, 256]             928             928
#           BasicConv2d-2     [1, 32, 127, 127]           9,280           9,280
#           BasicConv2d-3     [1, 32, 125, 125]          18,560          18,560
#             MaxPool2d-4     [1, 64, 125, 125]               0               0
#           BasicConv2d-5       [1, 64, 62, 62]           5,280           5,280
#           BasicConv2d-6       [1, 80, 62, 62]         138,624         138,624
#           BasicConv2d-7      [1, 192, 60, 60]         442,880         442,880
#               Block35-8      [1, 256, 29, 29]          77,440          77,440
#               Block35-9      [1, 256, 29, 29]          77,440          77,440
#              Block35-10      [1, 256, 29, 29]          77,440          77,440
#              Block35-11      [1, 256, 29, 29]          77,440          77,440
#              Block35-12      [1, 256, 29, 29]          77,440          77,440
#             Mixed_6a-13      [1, 256, 29, 29]       1,710,080       1,710,080
#              Block17-14      [1, 896, 14, 14]         690,048         690,048
#              Block17-15      [1, 896, 14, 14]         690,048         690,048
#              Block17-16      [1, 896, 14, 14]         690,048         690,048
#              Block17-17      [1, 896, 14, 14]         690,048         690,048
#              Block17-18      [1, 896, 14, 14]         690,048         690,048
#              Block17-19      [1, 896, 14, 14]         690,048         690,048
#              Block17-20      [1, 896, 14, 14]         690,048         690,048
#              Block17-21      [1, 896, 14, 14]         690,048         690,048
#              Block17-22      [1, 896, 14, 14]         690,048         690,048
#              Block17-23      [1, 896, 14, 14]         690,048         690,048
#             Mixed_7a-24      [1, 896, 14, 14]       3,346,176       3,346,176
#               Block8-25       [1, 1792, 6, 6]       1,600,768       1,600,768
#               Block8-26       [1, 1792, 6, 6]       1,600,768       1,600,768
#               Block8-27       [1, 1792, 6, 6]       1,600,768       1,600,768
#               Block8-28       [1, 1792, 6, 6]       1,600,768       1,600,768
#               Block8-29       [1, 1792, 6, 6]       1,600,768       1,600,768
#               Block8-30       [1, 1792, 6, 6]       1,600,768       1,600,768
#    AdaptiveAvgPool2d-31       [1, 1792, 6, 6]               0               0
#              Dropout-32       [1, 1792, 1, 1]               0               0
#               Linear-33             [1, 1792]         917,504         917,504
#          BatchNorm1d-34              [1, 512]           1,024           1,024
#               Linear-35              [1, 512]       2,884,086       2,884,086
# ==============================================================================
# Total params: 26,366,710
# Trainable params: 26,366,710
# Non-trainable params: 0
# ------------------------------------------------------------------------------

# %% [markdown]
# Setting the optimizer,scheduler and loss criterion for the model training

# %%
logits = model.logits.parameters()          ## optimizing only the logits
optimizer = optim.Adam(logits, lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)
criterion = nn.CrossEntropyLoss()

# %%
model , history = train_model(
    model = model , train_data_loader = train_loader , val_data_loader = validation_loader,train_dataset_size = len(train_indices),
    val_dataset_size = len(val_indices) , optimizer = optimizer , criterion = criterion , scheduler = scheduler , 
    device = device , n_epochs = 50
)
# Out:
# Epoch 1/50
# ----------
# Doing training on 9333 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 8.11 accuracy 0.05
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.55 accuracy 0.11
#
# Epoch 2/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 6.66 accuracy 0.09
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.25 accuracy 0.13
#
# Epoch 3/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 5.79 accuracy 0.11
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.17 accuracy 0.14
#
# Epoch 4/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 5.21 accuracy 0.13
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.19 accuracy 0.15
#
# Epoch 5/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 4.76 accuracy 0.16
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.23 accuracy 0.15
#
# Epoch 6/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 4.43 accuracy 0.20
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.30 accuracy 0.15
#
# Epoch 7/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 4.17 accuracy 0.24
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.34 accuracy 0.15
#
# Epoch 8/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.60 accuracy 0.36
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.32 accuracy 0.15
#
# Epoch 9/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.57 accuracy 0.37
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.15
#
# Epoch 10/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.53 accuracy 0.38
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.30 accuracy 0.15
#
# Epoch 11/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.48 accuracy 0.38
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.34 accuracy 0.15
#
# Epoch 12/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.43 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.16
#
# Epoch 13/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.44 accuracy 0.39
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.34 accuracy 0.15
#
# Epoch 14/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.42 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.15
#
# Epoch 15/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.44 accuracy 0.39
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.16
#
# Epoch 16/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.41 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.34 accuracy 0.15
#
# Epoch 17/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.43 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.31 accuracy 0.16
#
# Epoch 18/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.40 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.32 accuracy 0.15
#
# Epoch 19/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.43 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.32 accuracy 0.16
#
# Epoch 20/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.39 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.35 accuracy 0.15
#
# Epoch 21/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.45 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.35 accuracy 0.15
#
# Epoch 22/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.45 accuracy 0.39
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.34 accuracy 0.15
#
# Epoch 23/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.42 accuracy 0.41
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.35 accuracy 0.15
#
# Epoch 24/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.42 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.36 accuracy 0.15
#
# Epoch 25/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.44 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.15
#
# Epoch 26/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.42 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.35 accuracy 0.15
#
# Epoch 27/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.42 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.32 accuracy 0.15
#
# Epoch 28/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.42 accuracy 0.39
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.35 accuracy 0.15
#
# Epoch 29/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.43 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.32 accuracy 0.15
#
# Epoch 30/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.44 accuracy 0.39
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.16
#
# Epoch 31/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.41 accuracy 0.41
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.15
#
# Epoch 32/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.41 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.34 accuracy 0.16
#
# Epoch 33/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.41 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.16
#
# Epoch 34/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.39 accuracy 0.41
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.35 accuracy 0.16
#
# Epoch 35/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.44 accuracy 0.39
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.34 accuracy 0.15
#
# Epoch 36/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.43 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.31 accuracy 0.15
#
# Epoch 37/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.43 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.16
#
# Epoch 38/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.43 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.15
#
# Epoch 39/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.43 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.32 accuracy 0.15
#
# Epoch 40/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.42 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.15
#
# Epoch 41/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.41 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.16
#
# Epoch 42/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.40 accuracy 0.41
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.31 accuracy 0.15
#
# Epoch 43/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.43 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.34 accuracy 0.15
#
# Epoch 44/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.41 accuracy 0.41
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.33 accuracy 0.16
#
# Epoch 45/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.43 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.34 accuracy 0.15
#
# Epoch 46/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.43 accuracy 0.39
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.34 accuracy 0.16
#
# Epoch 47/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.45 accuracy 0.39
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.31 accuracy 0.16
#
# Epoch 48/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.45 accuracy 0.39
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.32 accuracy 0.15
#
# Epoch 49/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.44 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.31 accuracy 0.16
#
# Epoch 50/50
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.45 accuracy 0.40
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.32 accuracy 0.15
#
# Best val accuracy: 0.15730818688384055

# %% [markdown]
# Saving the model

# %%
torch.save( model.state_dict() , os.path.join(root_dir_path ,"Models" ,"lfw_KN95_vggface2_logits_50.pth") )

# %%
plot_training_history(history)

# %%
state_dict = torch.load(os.path.join(root_dir_path,'Models','lfw_KN95_vggface2_logits_50.pth'))
model.load_state_dict(state_dict=state_dict)
# Out:
# <All keys matched successfully>

# %%
print(eval_model(model = model , data_loader= test_loader , criterion=criterion,device=device , n_examples=len(test_indices)))
# Out:
# Doing validation on 1296 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# (tensor(0.2840, device='cuda:0', dtype=torch.float64), 7.35)

# %%
# !nvidia-smi
# Out:
# Sat Apr  3 07:45:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    28W /  70W |   1404MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)
criterion = nn.CrossEntropyLoss()

# %%
# !nvidia-smi
# Out:
# Sat Apr  3 07:45:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    28W /  70W |   1404MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
model , history = train_model(
    model = model , train_data_loader = train_loader , val_data_loader = validation_loader,train_dataset_size = len(train_indices),
    val_dataset_size = len(val_indices) , optimizer = optimizer , criterion = criterion , scheduler = scheduler , 
    device = device , n_epochs = 20
)
# Out:
# Epoch 1/20
# ----------
# Doing training on 9333 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 7.82 accuracy 0.07
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 58.36 accuracy 0.00
#
# Epoch 2/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 6.82 accuracy 0.11
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 11.51 accuracy 0.00
#
# Epoch 3/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 6.02 accuracy 0.14
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 15.11 accuracy 0.00
#
# Epoch 4/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 5.25 accuracy 0.18
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 20.09 accuracy 0.00
#
# Epoch 5/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 4.47 accuracy 0.23
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 20.81 accuracy 0.00
#
# Epoch 6/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.68 accuracy 0.29
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 13.98 accuracy 0.00
#
# Epoch 7/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 2.24 accuracy 0.54
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 10.53 accuracy 0.03
#
# Epoch 8/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.91 accuracy 0.65
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 20.29 accuracy 0.00
#
# Epoch 9/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.68 accuracy 0.71
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 13.17 accuracy 0.00
#
# Epoch 10/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.51 accuracy 0.77
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 31.35 accuracy 0.00
#
# Epoch 11/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.33 accuracy 0.82
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 12.79 accuracy 0.01
#
# Epoch 12/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.13 accuracy 0.88
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 8.69 accuracy 0.17
#
# Epoch 13/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.11 accuracy 0.89
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 9.64 accuracy 0.11
#
# Epoch 14/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.09 accuracy 0.89
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 11.90 accuracy 0.05
#
# Epoch 15/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.07 accuracy 0.89
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.91 accuracy 0.24
#
# Epoch 16/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.06 accuracy 0.90
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 8.56 accuracy 0.19
#
# Epoch 17/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.05 accuracy 0.90
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.88 accuracy 0.24
#
# Epoch 18/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.02 accuracy 0.91
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.60 accuracy 0.24
#
# Epoch 19/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.01 accuracy 0.91
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 8.11 accuracy 0.22
#
# Epoch 20/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.00 accuracy 0.91
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 8.89 accuracy 0.17
#
# Best val accuracy: 0.24132018859837118

# %%
torch.save( model.state_dict() , os.path.join(root_dir_path ,"Models" ,"lfw_KN95_full_vggface2_20.pth") )

# %%
plot_training_history(history)

# %%
print(eval_model(model = model , data_loader= test_loader , criterion=criterion,device=device , n_examples=len(test_indices)))
# Out:
# Doing validation on 1296 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# (tensor(0.4406, device='cuda:0', dtype=torch.float64), 7.57)

# %%
model = InceptionResnetV1(
    classify=True,
    pretrained='casia-webface',
    num_classes=len(dataset.class_to_idx)
).to(device)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=115887415.0), HTML(value='')))

# %%
optimizer = optim.Adam(model.logits.parameters(), lr=0.001)             ## optmizing only the logits
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)
criterion = nn.CrossEntropyLoss()

# %%
model , history = train_model(
    model = model , train_data_loader = train_loader , val_data_loader = validation_loader,train_dataset_size = len(train_indices),
    val_dataset_size = len(val_indices) , optimizer = optimizer , criterion = criterion , scheduler = scheduler , 
    device = device , n_epochs = 20
)
# Out:
# Epoch 1/20
# ----------
# Doing training on 9333 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 7.91 accuracy 0.08
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.26 accuracy 0.14
#
# Epoch 2/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 5.62 accuracy 0.19
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 6.81 accuracy 0.18
#
# Epoch 3/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 4.04 accuracy 0.32
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 6.74 accuracy 0.19
#
# Epoch 4/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 2.89 accuracy 0.53
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 6.79 accuracy 0.20
#
# Epoch 5/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 2.07 accuracy 0.70
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 6.83 accuracy 0.21
#
# Epoch 6/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.58 accuracy 0.76
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 6.95 accuracy 0.21
#
# Epoch 7/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.29 accuracy 0.80
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.03 accuracy 0.21
#
# Epoch 8/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.00 accuracy 0.85
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.03 accuracy 0.21
#
# Epoch 9/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.98 accuracy 0.85
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.02 accuracy 0.21
#
# Epoch 10/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.96 accuracy 0.85
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.05 accuracy 0.21
#
# Epoch 11/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.95 accuracy 0.85
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.03 accuracy 0.21
#
# Epoch 12/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.93 accuracy 0.86
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.04 accuracy 0.21
#
# Epoch 13/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.93 accuracy 0.85
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.03 accuracy 0.22
#
# Epoch 14/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.95 accuracy 0.85
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.03 accuracy 0.21
#
# Epoch 15/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.91 accuracy 0.86
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.03 accuracy 0.21
#
# Epoch 16/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.93 accuracy 0.86
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.06 accuracy 0.22
#
# Epoch 17/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.92 accuracy 0.86
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.03 accuracy 0.21
#
# Epoch 18/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.93 accuracy 0.86
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.03 accuracy 0.21
#
# Epoch 19/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.91 accuracy 0.86
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.03 accuracy 0.21
#
# Epoch 20/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.92 accuracy 0.86
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.05 accuracy 0.21
#
# Best val accuracy: 0.21517359622803256

# %%
torch.save( model.state_dict() , os.path.join(root_dir_path ,"Models" ,"lfw_KN95_casiawebface_20.pth") )

# %%
plot_training_history(history)

# %%
print(eval_model(model = model , data_loader= test_loader , criterion=criterion,device=device , n_examples=len(test_indices)))
# Out:
# Doing validation on 1296 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# (tensor(0.3904, device='cuda:0', dtype=torch.float64), 7.01)

# %%
# !nvidia-smi
# Out:
# Sun Apr  4 04:05:48 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   77C    P0    34W /  70W |  10002MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
torch.cuda.empty_cache()

# %%
model = InceptionResnetV1(
    classify=True,
    pretrained='casia-webface',
    num_classes=len(dataset.class_to_idx)
).to(device)

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)
criterion = nn.CrossEntropyLoss()

# %%
model , history = train_model(
    model = model , train_data_loader = train_loader , val_data_loader = validation_loader,train_dataset_size = len(train_indices),
    val_dataset_size = len(val_indices) , optimizer = optimizer , criterion = criterion , scheduler = scheduler , 
    device = device , n_epochs = 20
)
# Out:
# Epoch 1/20
# ----------
# Doing training on 9333 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 7.78 accuracy 0.08
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 11.29 accuracy 0.00
#
# Epoch 2/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 6.61 accuracy 0.13
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 66.92 accuracy 0.00
#
# Epoch 3/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 5.52 accuracy 0.18
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 10.37 accuracy 0.00
#
# Epoch 4/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 4.45 accuracy 0.25
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 20.85 accuracy 0.00
#
# Epoch 5/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 3.36 accuracy 0.34
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 21.46 accuracy 0.00
#
# Epoch 6/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 2.23 accuracy 0.51
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 14.67 accuracy 0.00
#
# Epoch 7/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 1.21 accuracy 0.75
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 54.51 accuracy 0.00
#
# Epoch 8/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.37 accuracy 0.95
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 15.39 accuracy 0.00
#
# Epoch 9/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.24 accuracy 0.98
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 20.50 accuracy 0.00
#
# Epoch 10/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.19 accuracy 0.98
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 19.62 accuracy 0.00
#
# Epoch 11/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.15 accuracy 0.99
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 16.79 accuracy 0.01
#
# Epoch 12/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.12 accuracy 0.99
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.80 accuracy 0.31
#
# Epoch 13/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.12 accuracy 0.99
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 8.16 accuracy 0.29
#
# Epoch 14/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.12 accuracy 0.99
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.64 accuracy 0.32
#
# Epoch 15/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.11 accuracy 0.99
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.95 accuracy 0.28
#
# Epoch 16/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.11 accuracy 0.99
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 8.14 accuracy 0.29
#
# Epoch 17/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.11 accuracy 0.99
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.63 accuracy 0.29
#
# Epoch 18/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.11 accuracy 0.99
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.55 accuracy 0.32
#
# Epoch 19/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.10 accuracy 0.99
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.79 accuracy 0.31
#
# Epoch 20/20
# ----------
# Doing training on 9333 samples
#  Processing batch 1/145
#  Processing batch 11/145
#  Processing batch 21/145
#  Processing batch 31/145
#  Processing batch 41/145
#  Processing batch 51/145
#  Processing batch 61/145
#  Processing batch 71/145
#  Processing batch 81/145
#  Processing batch 91/145
#  Processing batch 101/145
#  Processing batch 111/145
#  Processing batch 121/145
#  Processing batch 131/145
#  Processing batch 141/145
# Train loss 0.10 accuracy 0.99
# Doing validation on 2333 samples
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# Validation  loss 7.57 accuracy 0.32
#
# Best val accuracy: 0.3210458636948135

# %%
torch.save( model.state_dict() , os.path.join(root_dir_path ,"Models" ,"lfw_KN95_full_casiawebface_20.pth") )

# %%
plot_training_history(history)

# %%
print(eval_model(model = model , data_loader= test_loader , criterion=criterion,device=device , n_examples=len(test_indices)))
# Out:
# Doing validation on 1296 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#  Processing batch 1/36
#  Processing batch 11/36
#  Processing batch 21/36
#  Processing batch 31/36
# (tensor(0.5741, device='cuda:0', dtype=torch.float64), 7.55)
